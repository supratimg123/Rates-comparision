# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

# %%
df=pd.read_excel("/home/user/Desktop/env2/VAR/Libor_sofr_org_value_adjusted.xlsx")

# %%
df.fillna(method='ffill',inplace=True)
df.index=df['Date']
df.isnull().sum()
# Out:
# Date                    0
# LIBOR ON                0
# LIBOR 1W                0
# LIBOR 1M                0
# LIBOR 2M                0
# LIBOR 3M                0
# LIBOR 6M                0
# LIBOR 12M               0
# SOFR Index              0
# 30-Day Average SOFR     0
# 90-Day Average SOFR     0
# 180-Day Average SOFR    0
# dtype: int64

# %%
df.describe()
# Out:
#           LIBOR ON     LIBOR 1W     LIBOR 1M     LIBOR 2M     LIBOR 3M  \
# count  1342.000000  1342.000000  1342.000000  1342.000000  1342.000000
# mean      1.104412     1.141151     1.219097     1.297991     1.398436
# std       0.812008     0.811312     0.821114     0.824366     0.832577
# min       0.050750     0.079130     0.103000     0.133630     0.175250
# 25%       0.378200     0.401550     0.441250     0.532775     0.639138
# 50%       1.177220     1.193890     1.228055     1.257500     1.311530
# 75%       1.826035     1.910345     2.029082     2.110820     2.294107
# max       2.402750     2.430880     2.522380     2.652880     2.823750
#
#           LIBOR 6M    LIBOR 12M   SOFR Index  30-Day Average SOFR  \
# count  1342.000000  1342.000000  1342.000000          1342.000000
# mean      1.537947     1.737062     1.016310             1.529288
# std       0.815140     0.832636     0.017689             0.758700
# min       0.189500     0.275880     1.000000             0.011000
# 25%       0.909088     1.207912     1.000000             1.578630
# 50%       1.452220     1.751220     1.007513             1.741850
# 75%       2.229045     2.345410     1.037351             1.886722
# max       2.907880     3.144130     1.042077             2.502760
#
#        90-Day Average SOFR  180-Day Average SOFR
# count          1342.000000           1342.000000
# mean              1.574274              1.635313
# std               0.731220              0.707794
# min               0.035890              0.060340
# 25%               1.773250              1.864320
# 50%               1.778860              1.864320
# 75%               1.860607              1.864320
# max               2.450980              2.453260
